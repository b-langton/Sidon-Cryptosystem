# %%
import matplotlib
from matplotlib import pyplot as plt

# %%
data = [60.25, 98.8 ,213.8 ,766.2 ,4660,55830]
x = [3,4,5,6,7,8]

# %%
plt.plot(x,data)

# %%
plt.plot(x[:-1], data[:-1])

# %%
plt.title("Time to Complete Algebraic Attack vs k")
plt.ylabel("Time (ms)")
plt.xlabel("k")
plt.plot(x[:-1], data[:-1])
